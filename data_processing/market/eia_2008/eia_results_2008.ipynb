# %%
import numpy as np
import matplotlib.pyplot as plt
import functions_2008 as eia

# %%
eia.plot_data(total=True)

# %%
eia.plot_data(top_producers=True)

# %%
eia.plot_data(top_renewables=True)

# %%
eia.plot_data(fuel_breakdown=True)

# %%
eia.plot_data(use=True)
